# %% [markdown]
# <a href="https://colab.research.google.com/github/Indhresen/1/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib
#
# In this session we will discuss:
# - Line plot
# - Bar charts
# - Pie charts
# - Box plot
# - Scatter plot
# - Bubble charts
# - Subplots
#
#
#
# - The libraries in Python come with lots of different features that enable users to make highly customised, elegant, and interactive plots.
#
# - In this section, we will cover the usage of Matplotlib and Seaborn
#
# - Within Matplotlib and Seaborn, we will be covering a few of the most used plots in the data science world for easy visualisation.
#
# - Later on, we’ll review another powerful feature in Python visualisations - the subplot - and cover a basic walkthrough for creating subplots.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## Line plot
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html

# %%
df = pd.read_excel("employee_satisfaction.xlsx")
df = df.dropna()
df
# Out:
#       Name   Age   Income  Gender   Level        Priorities  \
# 0     Alan  20.0  33000.0    Male  Junior           Freedom
# 3    David  23.0  22000.0    Male  Junior           Freedom
# 4     Luke  34.0  65000.0    Male  Senior  Entrepreneurship
# 5    Maria  23.0  22000.0  Female  Junior          Learning
# 7    Tanya  10.0  51000.0  Female  Senior           Freedom
# 8    Allen  45.0  43000.0  Female     Mid         Expertise
# 9   Hileni  27.0  44000.0  Female     Mid        Management
# 10     Tim  38.0  45000.0    Male     Mid           freedom
# 11   Henry  23.0  27000.0    Male  Junior      Life Balance
# 12  Thomas  49.0  65000.0    Male  Senior        Management
# 13  Olivia  43.0  60000.0  Female  Senior         Expertise
# 14   Harry  60.0  85000.0    Male  Senior  Entrepreneurship
# 15   Freya  27.0  23000.0  Female  Junior          Learning
# 16  Thomas  49.0  65000.0    Male  Senior        Management
# 19     Leo  37.0  40000.0    Male     Mid             Hello
# ...

# %%
df = df.sort_values(by = ["Age", "Income"], ascending=True).reset_index()
df
# Out:
#     index    Name   Age   Income  Gender   Level        Priorities  \
# 0       7   Tanya  10.0  51000.0  Female  Senior           Freedom
# 1       0    Alan  20.0  33000.0    Male  Junior           Freedom
# 2       3   David  23.0  22000.0    Male  Junior           Freedom
# 3       5   Maria  23.0  22000.0  Female  Junior          Learning
# 4      11   Henry  23.0  27000.0    Male  Junior      Life Balance
# 5      15   Freya  27.0  23000.0  Female  Junior          Learning
# 6       9  Hileni  27.0  44000.0  Female     Mid        Management
# 7      22  Hileni  27.0  44000.0  Female     Mid        Management
# 8       4    Luke  34.0  65000.0    Male  Senior  Entrepreneurship
# 9      19     Leo  37.0  40000.0    Male     Mid             Hello
# 10     10     Tim  38.0  45000.0    Male     Mid           freedom
# 11     21     Tim  38.0  45000.0    Male     Mid           Freedom
# 12     20  Sophia  41.0  52000.0  Female     Mid      Life Balance
# ...

# %%
plt.plot(df.index, df.Age)
plt.show()

# %% [markdown]
# Matplotlib offer a range of color palette, here is a list of palette:
#
# <img src='palette.png' width="400" height="400">

# %%
import numpy as np
ind = np.arange(10)
x1 = [8, 10, 11, 9, 10, 12, 13, 12, 14, 11]
x2 = [7.5, 9, 9.5, 11, 13, 13.5, 14, 14.5, 13, 13.5]

# %%
plt.plot(ind, x1)
plt.plot(ind, x2)
plt.show()

# %% [markdown]
# Some important attributes to make your visualisations meaningful
# - Title
# - xlabel
# - ylabel
# - linewidth
# - color
# - grid
# - legend
# - marker
# - markersize
# - linestyle
# - alpha
# - fontsize
# - xlimit
# - ylimit

# %% [markdown]
# ## Bar Charts
#
# - A bar chart is used when we want to compare metric values across different subgroups of the data. If we have a greater number of groups, a bar chart is preferred over a column chart.
#
# - We want to visualise the total revenue or sales generated for each region

# %%
plt.bar(df["Satisfaction"], df["Age"], color = ["beige", "wheat", "navajowhite", "tan", "darkkhaki"])
#plt.xticks(rotation=45)
plt.show()

# %%
plt.barh(df["Satisfaction"], df["Age"], color = ["beige", "wheat", "navajowhite", "tan", "darkkhaki"])
plt.show()

# %%
Age_count = df.groupby("Satisfaction")["Age"].count().to_frame().reset_index()
Age_count
# Out:
#          Satisfaction  Age
# 0    Highly Satisfied    4
# 1  Highly Unsatisfied    4
# 2             Neutral    4
# 3           Satisfied    3
# 4         Unsatisfied    4

# %%
plt.bar(Age_count["Satisfaction"], Age_count["Age"], color = ["lightsteelblue", "lightsteelblue", "lightsteelblue", "slategrey", "lightsteelblue"])
# Out:
# <BarContainer object of 5 artists>

# %%
income = df.groupby("Satisfaction")["Income"].mean().to_frame().reset_index()

# %%
income
# Out:
#          Satisfaction        Income
# 0    Highly Satisfied  43250.000000
# 1  Highly Unsatisfied  54500.000000
# 2             Neutral  33250.000000
# 3           Satisfied  47333.333333
# 4         Unsatisfied  56250.000000

# %%
plt.bar(income["Satisfaction"], income["Income"], width = 0.90, color = ["lightsteelblue", "lightsteelblue", "slategrey", "lightsteelblue", "lightsteelblue"])
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# # Pie Chart
#
# https://matplotlib.org/stable/gallery/pie_and_polar_charts/pie_features.html

# %%
Priorities = df.groupby("Priorities")["Name"].count()

plt.pie(Priorities, labels = Priorities.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x2114d390c70>,
# ...
#  [Text(1.0403989649906822, 0.3571694186885514, 'Entrepreneurship'),
#   Text(0.44186498201010455, 1.0073506527883973, 'Expertise'),
#   Text(-0.7450097048603818, 0.8092963237676586, 'Freedom'),
#   Text(-1.0999999999999999, 2.5747358557800545e-08, 'Hello'),
#   Text(-0.9674211366466228, -0.523542113272043, 'Learning'),
#   Text(-0.44186498201010493, -1.007350652788397, 'Life Balance'),
#   Text(0.6016429671278825, -0.9208831305358774, 'Management'),
#   Text(1.0849974335199486, -0.18105405064544908, 'freedom')])

# %%
plt.pie(Priorities, labels = Priorities.index, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2114d325250>,
# ...
#  [Text(1.0403989649906822, 0.3571694186885514, 'Entrepreneurship'),
#   Text(0.44186498201010455, 1.0073506527883973, 'Expertise'),
#   Text(-0.7450097048603818, 0.8092963237676586, 'Freedom'),
#   Text(-1.0999999999999999, 2.5747358557800545e-08, 'Hello'),
#   Text(-0.9674211366466228, -0.523542113272043, 'Learning'),
#   Text(-0.44186498201010493, -1.007350652788397, 'Life Balance'),
#   Text(0.6016429671278825, -0.9208831305358774, 'Management'),
#   Text(1.0849974335199486, -0.18105405064544908, 'freedom')],
#  [Text(0.567490344540372, 0.194819682921028, '10.5%'),
#   Text(0.24101726291460246, 0.5494639924300347, '15.8%'),
#   Text(-0.4063689299238446, 0.4414343584187228, '21.1%'),
#   Text(-0.5999999999999999, 1.4044013758800295e-08, '5.3%'),
#   Text(-0.5276842563527032, -0.2855684254211144, '10.5%'),
#   Text(-0.24101726291460265, -0.5494639924300347, '10.5%'),
#   Text(0.3281688911606631, -0.5022998893832058, '21.1%'),
# ...

# %% [markdown]
# # Box Plot
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.boxplot.html

# %%
df
# Out:
#     index    Name   Age   Income  Gender   Level        Priorities  \
# 0       7   Tanya  10.0  51000.0  Female  Senior           Freedom
# 1       0    Alan  20.0  33000.0    Male  Junior           Freedom
# 2       3   David  23.0  22000.0    Male  Junior           Freedom
# 3       5   Maria  23.0  22000.0  Female  Junior          Learning
# 4      11   Henry  23.0  27000.0    Male  Junior      Life Balance
# 5      15   Freya  27.0  23000.0  Female  Junior          Learning
# 6       9  Hileni  27.0  44000.0  Female     Mid        Management
# 7      22  Hileni  27.0  44000.0  Female     Mid        Management
# 8       4    Luke  34.0  65000.0    Male  Senior  Entrepreneurship
# 9      19     Leo  37.0  40000.0    Male     Mid             Hello
# 10     10     Tim  38.0  45000.0    Male     Mid           freedom
# 11     21     Tim  38.0  45000.0    Male     Mid           Freedom
# 12     20  Sophia  41.0  52000.0  Female     Mid      Life Balance
# ...

# %%
plt.boxplot(df["Age"])
plt.show()

# %%
df = pd.read_csv("Car_sales.csv")

# %%
df.describe()
# Out:
#        Number of Review      Rating          Price        Mileage  \
# count       1000.000000  973.000000    1000.000000    1000.000000
# mean         115.826000    4.204522   13146.772000   64004.939000
# std          150.024702    0.281092   16115.759581   40778.018506
# min            0.000000    3.500000     895.000000       0.000000
# 25%           23.000000    4.000000    3571.250000   27580.000000
# 50%           57.000000    4.000000    5992.500000   65000.000000
# 75%          151.000000    4.500000   16500.000000   94000.000000
# max          620.000000    5.000000  109995.000000  330453.000000
#
#               Year        Doors
# count  1000.000000  1000.000000
# mean   2012.947000     4.567000
# std       5.535959     0.879935
# min    1996.000000     2.000000
# 25%    2009.000000     5.000000
# 50%    2012.000000     5.000000
# 75%    2019.000000     5.000000
# max    2023.000000     6.000000

# %%
data = [df["Price"].tolist(), df["Mileage"].tolist()]

# %%
plt.boxplot(data)
plt.show()

# %% [markdown]
# # Scatter plot
#
# https://realpython.com/visualizing-python-plt-scatter/

# %%
df.columns
# Out:
# Index(['Titles', 'Number of Review', 'Rating', 'Location', 'Price', 'Mileage',
#        'Year', 'Fuel type', 'Transmission', 'Body type', 'Colour', 'Doors',
#        'Engine size', 'CO2 Emissions'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Number of Review      Rating          Price        Mileage  \
# count       1000.000000  973.000000    1000.000000    1000.000000
# mean         115.826000    4.204522   13146.772000   64004.939000
# std          150.024702    0.281092   16115.759581   40778.018506
# min            0.000000    3.500000     895.000000       0.000000
# 25%           23.000000    4.000000    3571.250000   27580.000000
# 50%           57.000000    4.000000    5992.500000   65000.000000
# 75%          151.000000    4.500000   16500.000000   94000.000000
# max          620.000000    5.000000  109995.000000  330453.000000
#
#               Year        Doors
# count  1000.000000  1000.000000
# mean   2012.947000     4.567000
# std       5.535959     0.879935
# min    1996.000000     2.000000
# 25%    2009.000000     5.000000
# 50%    2012.000000     5.000000
# 75%    2019.000000     5.000000
# max    2023.000000     6.000000

# %%
plt.scatter(df["Price"], df["Mileage"], alpha = 0.5)

# %%
df = pd.read_excel("employee_satisfaction.xlsx")
df = df.dropna()

plt.scatter(df["Age"], df["Income"], alpha=0.5)

# %% [markdown]
# What can we infer from this scatter plot?

# %% [markdown]
# ## Bubble Charts

# %%
np.random.seed(42)
N = 100
x = np.random.normal(170, 20, N)
y = x + np.random.normal(5, 25, N)
colors = np.random.rand(N)
area = (25 * np.random.rand(N))**2

# %%
df = pd.DataFrame({
    'X': x,
    'Y': y,
    'Colors': colors,
    "bubble_size":area})
df.head()
# Out:
#             X           Y    Colors  bubble_size
# 0  179.934283  149.550015  0.877373   553.972491
# 1  167.234714  161.718581  0.740769    93.172029
# 2  182.953771  179.385908  0.697016   577.429562
# 3  200.460597  185.403665  0.702484   512.287366
# 4  165.316933  166.284790  0.359491    23.958855

# %%
plt.style.use('ggplot')
plt.scatter('X', 'Y', s='bubble_size',alpha=0.5, data=df)
plt.xlabel("X", size=16)
plt.ylabel("y", size=16)
# Out:
# Text(0, 0.5, 'y')

# %%
plt.scatter('X', 'Y',s='bubble_size',c='Colors',alpha=0.6, data=df)
plt.xlabel("X", size=16)
plt.ylabel("y", size=16)


#plt.scatter(df.X, df.Y, s=df.bubble_size, color=["red", "green", "blue", "grey", "green"])
# Out:
# Text(0, 0.5, 'y')

# %%
plt.style.use('ggplot')
plt.scatter('X', 'Y',alpha=0.5, c='Colors', data=df)
plt.xlabel("X", size=16)
plt.ylabel("y", size=16)
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# # Subplots
# https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_xlabel.html

# %%
x = np.arange(1,50,2)
y = np.power(x,2)
z = np.power(x, 3)
w = np.sin(x)

# %%
fig, ax = plt.subplots(3, figsize=(10, 5))

ax[0].plot(x, y, marker="o")
ax[0].set_ylabel("square")
ax[0].set_xticklabels([])


ax[1].plot(x, z, c="salmon")
ax[1].set_xticklabels([])


ax[2].plot(x, w, c= "lime")

#ax.set_title('A single plot')

# %% [markdown]
# https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_xlabel.html

# %% [markdown]
# # Matplotlib styles and rcparam
#
# styles and rcparam are used to customize default settings.

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# # References
#
# https://jakevdp.github.io/PythonDataScienceHandbook/04.11-settings-and-stylesheets.html#:~:text=The%20available%20styles%20are%20listed%20in%20plt.style.available%20%E2%80%94here,plt.style.available%5B%3A5%5D%20Out%20%3A%20%5B%27fivethirtyeight%27%2C%20%27seaborn-pastel%27%2C%20%27seaborn-whitegrid%27%2C%20%27ggplot%27%2C%20%27grayscale%27%5D
#
#
# https://matplotlib.org/stable/tutorials/introductory/customizing.html
